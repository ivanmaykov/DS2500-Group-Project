# %%
import pandas as pd

a = pd.read_csv('https://production-gradescope-uploads.s3-us-west-2.amazonaws.com/uploads/text_file/file/443137287/18_Artificial_synesthesia.csv?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIAIGIENPBVZV37ZJPA%2F20230420%2Fus-west-2%2Fs3%2Faws4_request&X-Amz-Date=20230420T002333Z&X-Amz-Expires=10800&X-Amz-SignedHeaders=host&X-Amz-Signature=a48f9a145d64b8744cfdba6a8fabac75ae2228dd5c075df02deb9c3f47f2006d')
a = a[['positive','to improve','effective score']]
with pd.option_context('display.max_rows', None):  # more options can be specified also
    display(a)

a['effective score'].mean()
# Out:
#                                              positive
# 0   I like how detailed their Data Description sec...  \
# 1                                          Intersting
# 2                    Very clear goals, easy to follow
# 3   Did a good job introducing the topic and I fou...
# 4   Interesting project and I enjoyed learning abo...
# 5   Explaining the dataset features was very helpf...
# 6   This is such an interesting topic and I really...
# 7   I think that this project overall was a very u...
# 8                                      nice takeaways
# 9                              interesting discovery!
# 10  the description of audio signal info was very ...
# 11  All of their visuals were excellent in both th...
# 12  Good description of data, i knew what was goin...
# 13  Beautiful aesthetics, I like how they describe...
# 14  described what each feature was for those who ...
# 15  love how you adapted your project instead of g...
# 16  Nice choice of topic. And description of dataset
# 17  The project topic was really interesting and t...
# 18  it is a very hard project to predict the genre...
# 19  I like how you explained why artificial synthe...
# 20  The before and after of cleaning the dataset i...
# 21  I liked some of your takeaways on how you were...
# 22  Very well spoken, very nice description of models
# 23  Clearly explained your process and takeaways\n...
# 24  I liked how everything flowed, thought it was ...
# 25  i like that you inlcuded feature importance an...
# 26  The feature importance for individual genres g...
# 27  The idea to use audio signal information was a...
# 28  their topic is very interesting. They tried to...
# 29  Overall great use of visualizations that we co...
# 30  Loved the feature importance graph for each ge...
# 31  Slides are engaging and machine learning is we...
# 32  Nice slide theme. Its very interesting to me t...
# 33  Really a standout presentation. They covered e...
# 34  Very unique approach to grouping music in with...
# 35  I liked the plot of the feature importance for...
# 36  Liked the explanation of their visuals and ML ...
# 37  The explanation of the attributes were really ...
# 38  Good presentation skills and organization, as ...
# 39  Good juts outlining the goal before conducting...
# 40                              Interesting  findings
# 41         The graphs and results were well explained
# 42  The backgrounds of slides/visualizations were ...
# 43  I thought your project was incredibly interest...
# 44  Confusion matrix had very good accuracy, indic...
# 45  I think the various depictions of feature impo...
# 46  I really like how the presentation was laid ou...
# 47  side note - Very nice looking slides\n\nThey g...
# 48  There was good depth in the presentation and I...
# 49  the feature importance for individual genres g...
# 50  This team did a really good job with visualizi...
# 51  Liked the explanations on the parameters that ...
# 52                               Interesting insights
# 53  Great job describing background and process ne...
# 54  Discussion around reason behind pivoting topic...
# 55  Good job talking about the things in the datas...
# 56  Data introduction and explanation on the Featu...
# 57  I like the creativity they added to formatting...
# 58  The confusion matrix was helpful in understand...
# 59  Good job in explaining scientific terms used i...
# 60  They explained the confusion matrix better the...
# 61  I like how they went into a lot of depth with ...
# 62  Their visualization for the feature importance...
# 63  It was great how in depth you went with the et...
# 64  I like the visualizations and i thought the to...
# 65  Really great Idea and presentation into someth...
# 66  I liked the Our Goal slide because it gave me ...
# 67  They chose a really interesting topic of predi...
# 68  I really like how thorough the ethical conside...
# 69                                  Really cool topic
# 70  The overall presentation was easy to follow an...
# 71  the ethical considerations regarding racial bi...
# 72  good problem solving skills by adjusting and m...
# 73  Slides were very clear easy to follow and with...
# 74  I really like the data visualization of the fe...
# 75  I liked the shift in research direction once i...
# 76  the feature importance graph was cool to see b...
#
#                                            to improve  effective score
# 0   It would have been nice to see an r2 score for...                6
# 1                                    very complicated                5
# 2   Some of the slides can be a little wordy, coul...                5
# 3   I think too much time was spent just explainin...                4
# 4   There was a lot of text on some slides, maybe ...                6
# 5   Why do you think some obvious genres were conf...                5
# 6   There was a lot of time spent explaining conte...                6
# 7   I do think that having a bit more clarity with...                6
# 8   what "unnecessary features" were removed? it w...                2
# 9   making the legend outside of the graph would b...                6
# 10                                     no complaints!                5
# 11  I think they could have explained their final ...                5
# 12  could've been interesting to see what clusteri...                6
# 13              None, I thought it was very well done                6
# 14                    slides were somewhat text heavy                5
# 15  a touch hard to understand, but that may just ...                5
# 16                                    No suggestions                 6
# 17  I think you guys could have maybe tried to pre...                5
# 18                                 everything is good                6
# 19  I think some of the explanations had terminolo...                6
# 20  I would have enjoyed a slightly different fram...                6
# 21  The feature importance scatter plot thing for ...                6
# 22                      Nothing that stood out to me.                6
# 23  A little too much text on some of the slides, ...                6
# 24  maybe a little more information, in depth, but...                4
# 25  slides with text could benefit from bolding to...                6
# 26  Seeing a decision tree for this would've been ...                6
# 27  It may be interesting to consider why the clas...                6
# 28  Maybe they can talk more about how they decide...                6
# 29  Might want to consider future works and prefer...                6
# 30  I thought you guys were able to do everything ...                6
# 31             Time went over; A lot of text on slide                5
# 32  A cool twist on this project would have been t...                6
# 33  Genuinely one of the best presentations I saw ...                6
# 34  how to prevent poc artists from being left out...                5
# 35  renaming features so that they look better on ...                4
# 36  Could have left out the beginning of what didn...                5
# 37  maybe include more background on what goals pr...                6
# 38  The actual feature importance graph for every ...                5
# 39  I would expand a little bit more on the implic...                6
# 40                                       lots of info                5
# 41    The conclusion could be made more comprehensive                5
# 42  The actual features of the dataset seem more c...                6
# 43  I wish you had explain what all of the feature...                4
# 44  Could be better understood if the feature impo...                5
# 45  THey could have managed their time a bit bette...                6
# 46  I would've been interested to learn more about...                6
# 47  For their feature importance graph I wish they...                6
# 48  How are the genres grouped by and what happens...                6
# 49                                                NaN                6
# 50  While this isn't necessary, it might have been...                6
# 51  When explaining unfamiliar terms from the data...                4
# 52  Didn't fully understand the feature names on t...                6
# 53  like you mentioned, analysis might've been tou...                6
# 54  Bit more explanation of frequency signal -> ge...                6
# 55  I think there were things that just werent exp...                5
# 56   Maybe slightly excessive text on the last slide.                5
# 57  The feature importance graph could use a title...                5
# 58  I'm a little confused by how this project rela...                6
# 59  Feature importance was relatively low in consi...                4
# 60                                                NaN                6
# 61  They used an interesting feature importance pl...                5
# 62  A little more connection from the machine lear...                5
# 63  I wish you explored more about the reasonings ...                4
# 64                                                 na                4
# 65  Really good work nothing that I feel you guys ...                6
# 66  I would've liked more on who this model would ...                5
# 67  What additional features or datasets would've ...                5
# 68                      not really much to say here!                 6
# 69                                        No feedback                4
# 70  I wonder if the group used kfold when doing kn...                6
# 71  the graphs were a bit hard to read/understand ...                3
# 72  legends for graphs were sometimes a bit compli...                6
# 73  Maybe explain potential sources information th...                6
# 74  could include some tests of the model you buil...                5
# 75  I wished the graphs had titles. Sometimes I wa...                5
# 76  I would have been interested to see how a diff...                5
# 5.35064935064935
